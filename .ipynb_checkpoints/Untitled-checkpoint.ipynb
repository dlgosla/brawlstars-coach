# %%
import requests
import json
from urllib.request import urlopen
from bs4 import BeautifulSoup

#print("==============MENU=================")

def printProfile():
    print("==============프로필=================")
    print("이름: ", player_info["name"])
    print("배틀태그: ", player_info["tag"])
    print("총 트로피 수: ",player_info["trophies"])
    print("3 vs 3 승리 횟수: ",player_info["3vs3Victories"])
    print("솔로 승리횟수: ", player_info["soloVictories"])
    print("듀오 승리횟수: ", player_info["duoVictories"])

    print("===========가진 브롤러 정보============== ")
    for brawler in player_info["brawlers"]:
        print("브롤러 이름: ", brawler["name"])
        print("브롤러 파워: ", brawler["power"])
        print("브롤러 랭크: ", brawler["rank"])
        print("브롤러 트로피: ", brawler["trophies"])
        print("----------------------------------")
    print("===================================")

def selectMode():
    print("==============MENU=================")
    print("1. 잼그랩")
    print("2. 듀오 쇼다운")
    print("3. 하이스트")
    print("4. 바운티")
    print("5. 시즈팩토리")
    print("6. 브롤 볼")
    print("===================================")
    mode = int(input("모드를 선택해 주세요"))
    return mode
#def printPickRate(mode):

#battleTag = input("배틀태그를 입력해주세요 ex)#UYVQJ8Y: ")
#battleTag = battleTag[1:]
battleTag = "#UYVQJ8Y"
battleTag = battleTag[1:]
url = "https://api.brawlstars.com/v1/players/%23"+battleTag #플레이어 정보
apikey = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..AQPVLqY2HNPg2BHzG3uQc4zpvRhXyVV4IaNahR6Wl8qmh0UrHCjt4Po5N0lc8CuBkuVzKRJOefnyne_VcUdh7A"
response = requests.get(url,headers = {"Authorization":"Bearer "+ apikey})
player_info = response.json() #dict로 변환
#printProfile()
#mode = selectMode()

def crawling():
    url = "https://brawlstats.com/wiki/" + "brawlers"
    html = urlopen(url)  
    soup = BeautifulSoup(html, "html.parser") 
    bralwers = soup.select('._1v7A4DKYZQsz0-gBiHz_vB')
    pickRate = soup.select('._1QeRyIPGpDozg-VG3DwYQE')
    winRate =  soup.select('._1QeRyIPGpDozg-VG3DwYQE')
    for item in table:
        print(item.text)
        
    #print(table)
    #body = str(table.get_text())
    #print(body)


crawling()
# Out:
# [<div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000048.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Mr. P
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000049.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Jacky
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000044.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Sandy
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000028.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Pam
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000040.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Rosa
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000029.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Tara
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000039.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Carl
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000007.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Nita
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000013.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Poco
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000035.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Penny
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000045.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Emz
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000038.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Gene
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000050.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Sprout
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000006.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Jessie
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000015.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Bo
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000014.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Mortis
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000043.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               8-bit
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000051.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Gale
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000017.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Crow
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000016.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Spike
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000036.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Frank
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000047.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Max
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000034.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Darryl
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000018.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Piper
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000010.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Bull
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000037.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Leon
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000011.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Rico
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000012.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Barley
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000041.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Bibi
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000005.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Brock
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000042.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Tick
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000046.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Bea
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000009.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               El Primo
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000004.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Colt
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000003.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Shelly
#             </div></div>, <div class="_1v7A4DKYZQsz0-gBiHz_vB"><img alt="" class="_3cKIvSvqQRKmgLcOBnVaSd" src="https://cdn.brawlstats.com/player-thumbnails/28000008.png"/><div class="_3lMfMVxY-knKo2dnVHMCWG _21sSMvccqXG6cJU-5FNqzv" style="color:#FFFFFF;font-size:18px;">
#               Dynamike
#             </div></div>]
#
#               Mr. P
#
#
#               Jacky
#
#
#               Sandy
#
#
#               Pam
#
#
#               Rosa
#
#
#               Tara
#
#
#               Carl
#
#
#               Nita
#
#
#               Poco
#
#
#               Penny
#
#
#               Emz
#
#
#               Gene
#
#
#               Sprout
#
#
#               Jessie
#
#
#               Bo
#
#
#               Mortis
#
#
#               8-bit
#
#
#               Gale
#
#
#               Crow
#
#
#               Spike
#
#
#               Frank
#
#
#               Max
#
#
#               Darryl
#
#
#               Piper
#
#
#               Bull
#
#
#               Leon
#
#
#               Rico
#
#
#               Barley
#
#
#               Bibi
#
#
#               Brock
#
#
#               Tick
#
#
#               Bea
#
#
#               El Primo
#
#
#               Colt
#
#
#               Shelly
#
#
#               Dynamike
